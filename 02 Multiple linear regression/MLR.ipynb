# %% [markdown]
# ### multiple linear regression

# %% [markdown]
# #### multiple predictors and single target
# 1. y~ x1,x2,x3 ..., xn
# 2. y

# %% [markdown]
# ### step 1- Data ingestion -read the data using pandas dataframe

# %%
import pandas as pd

df = pd.read_csv("50_Startup.csv")
df.head()
# Out:
#          RND      ADMIN        MKT       STATE     PROFIT
# 0  165349.20  136897.80  471784.10    New York  192261.83
# 1  162597.70  151377.59  443898.53  California  191792.06
# 2  153441.51  101145.55  407934.54     Florida  191050.39
# 3  144372.41  118671.85  383199.62    New York  182901.99
# 4  142107.34   91391.77  366168.42     Florida  166187.94

# %% [markdown]
# ###

# %% [markdown]
# ## PROFIT ~ RND, ADMIN, MKT
# $PROFITpred = B0+B1*RND+b2ADMIN+B3*MKT $
#
# ### Step 2 - Perform Basic Data quality checks

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   RND     50 non-null     float64
#  1   ADMIN   50 non-null     float64
#  2   MKT     50 non-null     float64
#  3   STATE   50 non-null     object
#  4   PROFIT  50 non-null     float64
# dtypes: float64(4), object(1)
# memory usage: 2.1+ KB

# %%
df.isna().sum()
# Out:
# RND       0
# ADMIN     0
# MKT       0
# STATE     0
# PROFIT    0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# ### Step 3 - Visualize the data

# %%
import seaborn as sns

sns.pairplot(df, kind="reg", plot_kws={"line_kws": {"color": "red"}})

# %% [markdown]
# ### Step 4 - Seperate X and Y(PROFIT)

# %%
X = df.drop(columns=["PROFIT", "STATE"])
X.head()
# Out:
#          RND      ADMIN        MKT
# 0  165349.20  136897.80  471784.10
# 1  162597.70  151377.59  443898.53
# 2  153441.51  101145.55  407934.54
# 3  144372.41  118671.85  383199.62
# 4  142107.34   91391.77  366168.42

# %%
Y = df[["PROFIT"]]
Y.head()
# Out:
#       PROFIT
# 0  192261.83
# 1  191792.06
# 2  191050.39
# 3  182901.99
# 4  166187.94

# %% [markdown]
# ### Step 5 - Build linear regression model

# %%
from sklearn.linear_model import LinearRegression

# %%
model = LinearRegression()

model.fit(X, Y)
# Out:
# LinearRegression()

# %%
model.intercept_
# Out:
# array([50122.19298987])

# %%
model.coef_
# Out:
# array([[ 0.80571505, -0.02681597,  0.02722806]])

# %%
X.columns
# Out:
# Index(['RND', 'ADMIN', 'MKT'], dtype='object')

# %%
coefs = pd.Series(model.coef_.flatten(), index=X.columns)
coefs
# Out:
# RND      0.805715
# ADMIN   -0.026816
# MKT      0.027228
# dtype: float64

# %%
coefs.plot(kind="bar")
# Out:
# <Axes: >

# %% [markdown]
# ### Fitted Equation

# %% [markdown]
# $ Proditpred =50122.19+0.857*RND-0.0268*ADMIN+0.0272*MKT $

# %% [markdown]
# ### Following conclusions
# 1. if RND increases by 1 unit Profit will increase 0.8057
# 2. if ADMIN increase by 1 unit Profit will decrease by 0.0268
# 3. if MKT increases by 1 unit Profit will increase by 0.0272
#
# ### For increasing Profit RND budget is more important compared to other

# %% [markdown]
# ### Step 6 - Model Evaluation

# %%
model.score(X, Y)
# Out:
# 0.9507459940683246

# %%
ypred = model.predict(X)
ypred[0:5]
# Out:
# array([[192521.25289008],
#        [189156.76823227],
#        [182147.2790962 ],
#        [173696.70002553],
#        [172139.51418327]])

# %%
Y.head()
# Out:
#       PROFIT
# 0  192261.83
# 1  191792.06
# 2  191050.39
# 3  182901.99
# 4  166187.94

# %%
from sklearn.metrics import (
    root_mean_squared_error,
    mean_absolute_error,
    mean_absolute_percentage_error,
    r2_score,
)

# %%
def evaluate_model(model, x, y):
    # Predict results for x
    ypred = model.predict(x)
    # Calcualte different metrics
    rmse = root_mean_squared_error(y, ypred)
    mae = mean_absolute_error(y, ypred)
    mape = mean_absolute_percentage_error(y, ypred)
    r2 = r2_score(y, ypred)
    # Print the results
    print(f"RMSE : {rmse:.2f}")
    print(f"MAE : {mae:.2f}")
    print(f"MAPE : {mape:.2%}")
    print(f"R2 : {r2:.2%}")

# %%
evaluate_model(model, X, Y)
# Out:
# RMSE : 8855.34
# MAE : 6471.45
# MAPE : 10.60%
# R2 : 95.07%

# %% [markdown]
# ### R2 > 0.8 hence model is considered to be a good model
#
#
# ### Step 7 - Out of Sample prediction

# %%
X.head()
# Out:
#          RND      ADMIN        MKT
# 0  165349.20  136897.80  471784.10
# 1  162597.70  151377.59  443898.53
# 2  153441.51  101145.55  407934.54
# 3  144372.41  118671.85  383199.62
# 4  142107.34   91391.77  366168.42

# %%
rnd = 1_50_000
admin = 20_000
mkt = 30_000

xnew = [[rnd, admin, mkt]]

profit_pred = model.predict(xnew)
profit_pred
# Out:
# c:\Users\DELL\Desktop\Machine Learning\.venv\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([[171259.97305336]])
